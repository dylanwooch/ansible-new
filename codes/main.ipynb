# %%
from cyberark_auth import *
from database import *



#Get instance ID from database
instanceid = getPending()

for x in range(len(instanceid)):

    ec2id = instanceid[x][0]
    print(ec2id)
    #Get CyberArk ID from database
    cyberarkid = getID(ec2id)
    print(cyberarkid)

    #Login to CyberArk
    SESSIONID = loginUser() #Store Session ID to global variable
    SESSIONHEADER = {"content-type":"application/json", 'Authorization' : SESSIONID}
    

    #trigger login once
    #loop through login user

    #trigger admin once
    #loop through admin user


    #trigger all functional accounts once
    #loop through the status of each user

    for i in range(len(cyberarkid)):
        caid= cyberarkid[i][0]
        
        #Send API to get JSON using CyberArk ID (caid)
        result = sendapiRequest(UPDATEACCOUNTURL.format(caid), "",SESSIONHEADER, "GET")
        print(result)

        #declare variable
        id = result['id']
        tries = getTries(id)
        logger("Going in while loop")

        while tries[0][0] < 5:   
            if "status" in result['secretManagement']:
                if result['secretManagement']['status'] == "success":
                    updateStatus(id)
                    updateTries(id)
                    logger(id + " successfully updated ")
                    break

                elif result['secretManagement']['status'] == "failure":
                    role = getRoles(id)
                    if role == "admin" or "logon":
                        sendapiRequest(CHANGEURL.format(id),"",SESSIONHEADER, "POST")
                        updateTries(id)

                    elif role == "user":
                        sendapiRequest(RECONCILEURL.format(id),"",SESSIONHEADER, "POST")
                        updateTries(id)

            time.sleep(60)
            result = sendapiRequest(UPDATEACCOUNTURL.format(caid), "",SESSIONHEADER, "GET")



        
        




#Logoff
# sendapiRequest(LOGOFFURL,"", SESSIONHEADER, "POST")
# logger("Successfully logged out user: " + USERNAME)
# Out:
# i-036c0115056fe5c8c
# [('35_1895',), ('35_1896',), ('35_1897',), ('35_1898',), ('35_1899',)]
# 2022-08-06 17:29:07.446636 || Logging in user: Administrator
# 2022-08-06 17:29:07.446765 || Sending url request: /PasswordVault/API/Auth/Cyberark/Logon
# 2022-08-06 17:29:07.446774 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:29:07.519396 || 200 - OK
# 2022-08-06 17:29:07.519424 || Closed connection
# 2022-08-06 17:29:07.519573 || User [Administrator] successfully logged in
# 2022-08-06 17:29:07.519597 || Sending url request: /PasswordVault/API/Accounts/35_1895
# 2022-08-06 17:29:07.519602 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:29:07.664012 || 200 - OK
# 2022-08-06 17:29:07.664288 || Closed connection
# {'categoryModificationTime': 1659777901, 'id': '35_1895', 'name': 'Operating System-UnixSSH-54.255.179.75-cyberlogon', 'address': '54.255.179.75', 'userName': 'cyberlogon', 'platformId': 'UnixSSH', 'safeName': 'UnixAccount', 'secretType': 'password', 'secretManagement': {'automaticManagementEnabled': True, 'lastModifiedTime': 1659777480}, 'createdTime': 1659777480}
# 2022-08-06 17:29:07.675937 || Going in while loop
# 2022-08-06 17:30:07.736953 || Sending url request: /PasswordVault/API/Accounts/35_1895
# 2022-08-06 17:30:07.737159 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:30:07.930322 || 200 - OK
# 2022-08-06 17:30:07.930354 || Closed connection
# 2022-08-06 17:31:07.987799 || Sending url request: /PasswordVault/API/Accounts/35_1895
# 2022-08-06 17:31:07.987922 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:31:08.176320 || 200 - OK
# 2022-08-06 17:31:08.176377 || Closed connection
# 2022-08-06 17:32:08.235486 || Sending url request: /PasswordVault/API/Accounts/35_1895
# 2022-08-06 17:32:08.235750 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:32:08.445280 || 200 - OK
# 2022-08-06 17:32:08.445614 || Closed connection
# 2022-08-06 17:33:08.502921 || Sending url request: /PasswordVault/API/Accounts/35_1895
# 2022-08-06 17:33:08.503033 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:33:08.662334 || 200 - OK
# 2022-08-06 17:33:08.662363 || Closed connection
# 2022-08-06 17:34:08.720644 || Sending url request: /PasswordVault/API/Accounts/35_1895
# 2022-08-06 17:34:08.720754 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:34:08.848446 || 200 - OK
# 2022-08-06 17:34:08.848477 || Closed connection
# 2022-08-06 17:35:08.909724 || Sending url request: /PasswordVault/API/Accounts/35_1895
# 2022-08-06 17:35:08.909941 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:35:11.591198 || 200 - OK
# 2022-08-06 17:35:11.591276 || Closed connection
# 2022-08-06 17:35:11.634918 || Sending url request: /PasswordVault/API/Accounts/35_1895/Change
# 2022-08-06 17:35:11.634965 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:35:14.826450 || 400 - API request failed. Encountered an error. Bad Request
# b'{"ErrorCode":"CAWS00001E","ErrorMessage":"A CPM change task is not currently allowed."}'
# 2022-08-06 17:35:14.826593 || Opening connection to server: comp130.dywoo.local
# 2022-08-06 17:35:14.848408 || Closed connection. Terminating script...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/dywoo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3406: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
